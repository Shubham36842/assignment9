# %% [raw]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [raw]
# Ans:-Matplotlin is a library present in python used for data visualisation.Using this library      you can plot different type of chart .This help to show data in the chart form so that        relation can be obtained.
#
#    plot in Pyplot module
#    1.bar
#    2.scatter
#    3.histogram
#    4.line plot
#    5.contour

# %% [raw]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("x asis data")
plt.ylabel("y axis data")
plt.title("scatter plot")
plt.show()

# %% [raw]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [raw]
# Ans:-The subplots() function in the Pyplot module of the Matplotlib library is used to create      a figure and a set of subplots.
#      it takes three argument first argument defines x axis data second argument defines y          axis data and thirsd argument defines index of graph.

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.show()

# %% [raw]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [raw]
# Ans-Bar plots are a type of data visualization used to represent data in the form of             rectangular bars. The height of each bar represents the value of a data point, and the       width of each bar represents the category of the data. The Matplotlib library in Python       is widely used to create bar plots.

# %%
import matplotlib.pyplot as plt
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(x=company,height=profit)
plt.xlabel("company Name--")
plt.ylabel("Profit")
plt.show()

# %% [raw]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [raw]
# Ans-. Box plots are used to show distributions of numeric data values, especially when you         want to compare them between multiple groups. They are built to provide high-level           information at a glance, offering general information about a group of data's symmetry,       skew, variance, and outliers.

# %%
import matplotlib.pyplot as plt
import numpy as nm
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.boxplot([box1,box2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f48af2b23b0>,
#   <matplotlib.lines.Line2D at 0x7f48af2b2650>,
#   <matplotlib.lines.Line2D at 0x7f48af2b3610>,
#   <matplotlib.lines.Line2D at 0x7f48af2b38b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f48af2b28f0>,
#   <matplotlib.lines.Line2D at 0x7f48af2b2b90>,
#   <matplotlib.lines.Line2D at 0x7f48af2b3b50>,
#   <matplotlib.lines.Line2D at 0x7f48af2b3df0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f48af2b2110>,
#   <matplotlib.lines.Line2D at 0x7f48af2b3370>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f48af2b2e30>,
#   <matplotlib.lines.Line2D at 0x7f48af2f00d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f48af2b30d0>,
#   <matplotlib.lines.Line2D at 0x7f48af2f0370>],
#  'means': []}
